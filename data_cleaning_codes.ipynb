# %% [markdown]
# # Lagos House Rent Exploratory Analysis

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("C:/Users/dell/Downloads/lagos_rent/lagos-rent.csv")

# %%
df
# Out:
#                                                    Title  \
# 0      Newly Built 4 Bedroom Semi Detached House With Bq
# 1          Superb 4 Bedroom Semi Detached Duplex With Bq
# 2        Furnished 2 Bedroom Terrace Duplex For Rent !!!
# 3                           2 Bedroom Apartment For Rent
# 4                      4 Bedroom Terrace Duplex For Rent
# ...                                                  ...
# 53065  A Fairly Used But Clean Mini Flat At Fola Agor...
# 53066                                          Mini Flat
# 53067                                     2 Bedroom Flat
# 53068  Alone In The Compound Newly Renovated 3bedroom...
# 53069                                 Riomself Contained
#
#                                   More Info           Price  Serviced  \
# 0                  4 BEDROOM HOUSE FOR RENT  5,000,000/year         0
# 1                  4 BEDROOM HOUSE FOR RENT  5,000,000/year         0
# ...

# %%
df.describe(include='all')
# Out:
#                  Title                            More Info           Price  \
# count            53070                                53070           53070
# unique           22311                                  336             877
# top     3 Bedroom Flat  3 BEDROOM FLAT / APARTMENT FOR RENT  1,500,000/year
# freq              2354                                 8749            1569
# mean               NaN                                  NaN             NaN
# std                NaN                                  NaN             NaN
# min                NaN                                  NaN             NaN
# 25%                NaN                                  NaN             NaN
# 50%                NaN                                  NaN             NaN
# 75%                NaN                                  NaN             NaN
# max                NaN                                  NaN             NaN
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53070 entries, 0 to 53069
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Title         53070 non-null  object
#  1   More Info     53070 non-null  object
#  2   Price         53070 non-null  object
#  3   Serviced      53070 non-null  int64
#  4   Newly Built   53070 non-null  int64
#  5   Furnished     53070 non-null  int64
#  6   Bedrooms      53070 non-null  object
#  7   Bathrooms     53070 non-null  object
#  8   Toilets       53070 non-null  object
#  9   City          53070 non-null  object
#  10  Neighborhood  53070 non-null  object
# dtypes: int64(3), object(8)
# memory usage: 4.5+ MB

# %%
df.head()
# Out:
#                                                Title  \
# 0  Newly Built 4 Bedroom Semi Detached House With Bq
# 1      Superb 4 Bedroom Semi Detached Duplex With Bq
# 2    Furnished 2 Bedroom Terrace Duplex For Rent !!!
# 3                       2 Bedroom Apartment For Rent
# 4                  4 Bedroom Terrace Duplex For Rent
#
#                   More Info           Price  Serviced  Newly Built  Furnished  \
# 0  4 BEDROOM HOUSE FOR RENT  5,000,000/year         0            1          0
# 1  4 BEDROOM HOUSE FOR RENT  5,000,000/year         0            1          0
# 2  2 BEDROOM HOUSE FOR RENT       3,500,000         1            0          0
# 3  2 BEDROOM HOUSE FOR RENT       2,700,000         1            1          0
# 4  4 BEDROOM HOUSE FOR RENT       4,000,000         1            0          0
#
#   Bedrooms Bathrooms    Toilets   City  Neighborhood
# 0   4 beds   4 baths  5 Toilets  Lekki        Agungi
# 1   4 beds   4 baths  5 Toilets  Lekki   Other Lekki
# ...

# %%
df.tail()
# Out:
#                                                    Title  \
# 53065  A Fairly Used But Clean Mini Flat At Fola Agor...
# 53066                                          Mini Flat
# 53067                                     2 Bedroom Flat
# 53068  Alone In The Compound Newly Renovated 3bedroom...
# 53069                                 Riomself Contained
#
#                                   More Info    Price  Serviced  Newly Built  \
# 53065          1 BEDROOM MINI FLAT FOR RENT  500,000         0            1
# 53066          1 BEDROOM MINI FLAT FOR RENT  400,000         0            1
# 53067   2 BEDROOM FLAT / APARTMENT FOR RENT  600,000         0            0
# 53068  3 BEDROOM DETACHED BUNGALOW FOR RENT  950,000         0            0
# 53069       1 BEDROOM SELF CONTAIN FOR RENT  400,000         0            1
#
#        Furnished Bedrooms Bathrooms    Toilets  City Neighborhood
# 53065          0   1 beds   2 baths  2 Toilets  Yaba        Agoro
# ...

# %%
df[df.Price.str.contains('/day')]
# Out:
#                                         Title  \
# 105                  4 Bedroom Terrace Duplex
# 413                 6 Bedroom Detached Duplex
# 501                            2 Bedroom Flat
# 1123                             Office Space
# 1213                           2 Bedroom Flat
# ...                                       ...
# 48921                  Self Contain Apartment
# 49721                               Mini Flat
# 49788                               Mini Flat
# 49869                               Mini Flat
# 50572  Service Short Stay Mini Flat Apartment
#
#                                  More Info           Price  Serviced  \
# 105               4 BEDROOM HOUSE FOR RENT  78,000,000/day         1
# 413               6 BEDROOM HOUSE FOR RENT  15,000,000/day         0
# 501    2 BEDROOM FLAT / APARTMENT FOR RENT   2,500,000/day         1
# 1123   5 BEDROOM CO WORKING SPACE FOR RENT       6,500/day         1
# ...

# %%
df[df.Price.str.contains('/day')].Price.value_counts()
# Out:
# 800,000/day       4
# 2,000,000/day     4
# 60,000/day        4
# 4,500,000/day     3
# 100,000/day       3
# 3,500,000/day     3
# 2,500,000/day     3
# 45,000/day        2
# 25,000/day        2
# 15,000,000/day    2
# 6,000,000/day     2
# 20,000/day        2
# 12,000,000/day    2
# 3,000,000/day     2
# 120,000/day       2
# 70,000/day        2
# 8,000,000/day     2
# 70,000,000/day    2
# 90,000/day        2
# 22,500/day        2
# 1,800,000/day     2
# 1,000,000/day     2
# 7,000,000/day     2
# 85,000/day        1
# 1,500,000/day     1
# 900,000/day       1
# 7,000/day         1
# 78,000,000/day    1
# 400,000/day       1
# 5,000/day         1
# 1,500/day         1
# 10,500,000/day    1
# 1,600,000/day     1
# 12,000/day        1
# 1,200,000/day     1
# 30,000/day        1
# 12,500/day        1
# 130,000/day       1
# 138,000/day       1
# 80,000/day        1
# 41,250/day        1
# 6,500/day         1
# 3,600,000/day     1
# 15,000/day        1
# 6,500,000/day     1
# ...

# %%
df[df.Price.str.contains('/month')].Price.value_counts()
# Out:
# 350,000/month          7
# 300,000/month          6
# 200,000/month          5
# 250,000/month          5
# 50,000/month           4
# 1,200,000/month        4
# 100,000/month          3
# 150,000/month          3
# 1,300,000/month        2
# 3,000,000/month        2
# 900,000/month          2
# 120,000/month          2
# 700,000/month          2
# 8,000/month            2
# 800,000/month          2
# 85,000/month           2
# 2,500,000/month        2
# 500,000/month          2
# 370,000/month          2
# 400,000/month          2
# 850,000/month          2
# 1,500,000/month        2
# 261,000/month          2
# 165,000/month          1
# 320,000/month          1
# 3,500,000/month        1
# 500/month              1
# 600,000/month          1
# 185,000/month          1
# 5,500,000/month        1
# 1,850,000/month        1
# 450,000/month          1
# 35,000/month           1
# 65,000/month           1
# 750,000/month          1
# 6,000/month            1
# 40,000/month           1
# ...

# %%
df[df["More Info"].str.contains('RENT')]
# Out:
#                                                    Title  \
# 0      Newly Built 4 Bedroom Semi Detached House With Bq
# 1          Superb 4 Bedroom Semi Detached Duplex With Bq
# 2        Furnished 2 Bedroom Terrace Duplex For Rent !!!
# 3                           2 Bedroom Apartment For Rent
# 4                      4 Bedroom Terrace Duplex For Rent
# ...                                                  ...
# 53065  A Fairly Used But Clean Mini Flat At Fola Agor...
# 53066                                          Mini Flat
# 53067                                     2 Bedroom Flat
# 53068  Alone In The Compound Newly Renovated 3bedroom...
# 53069                                 Riomself Contained
#
#                                   More Info           Price  Serviced  \
# 0                  4 BEDROOM HOUSE FOR RENT  5,000,000/year         0
# 1                  4 BEDROOM HOUSE FOR RENT  5,000,000/year         0
# ...

# %%
len(df[df.Price.str.contains('/day')])
# Out:
# 90

# %%
df = df[~df.Price.str.contains('/day')]

# %%
dirty_df = df.copy()

# %% [markdown]
# # Dropping price/sqm rows
#
# Without the total sqm of the apartment, it is impossible to determine how much the apartment really costs.
#
# Hence, the need to drop rows where the `Price` column contains `/sqm`.

# %%
df.Price[df.Price.str.contains('/sqm')]
# Out:
# 2477         60,000/sqm
# 3192        350,000/sqm
# 6697         80,000/sqm
# 6957         85,000/sqm
# 7387        150,000/sqm
# 8120         90,000/sqm
# 9377         50,000/sqm
# 9888         75,000/sqm
# 9926     70,000,000/sqm
# 10634        75,000/sqm
# 10851        35,000/sqm
# 11049     6,000,000/sqm
# 11338    90,000,000/sqm
# 11535        60,000/sqm
# 11596        70,000/sqm
# 12134       130,000/sqm
# 12136       130,000/sqm
# 12322        60,000/sqm
# 12742        70,000/sqm
# 13109       100,000/sqm
# 13222     1,500,000/sqm
# 13291     3,500,000/sqm
# 13462        35,000/sqm
# 13857     3,500,000/sqm
# 13885     2,300,000/sqm
# 20879        50,000/sqm
# 21400        40,000/sqm
# 21500     8,000,000/sqm
# 21509        70,000/sqm
# 21734        65,000/sqm
# 21743       550,000/sqm
# 22542        60,000/sqm
# 22546        38,000/sqm
# 24246        40,000/sqm
# 24949        65,000/sqm
# 25496        35,000/sqm
# 27231       100,000/sqm
# 27290       350,000/sqm
# ...

# %%
len(df.Price[df.Price.str.contains('/sqm')])
# Out:
# 59

# %%
df.shape
# Out:
# (52980, 11)

# %%
df.shape[0] - 59
# Out:
# 52921

# %%
len(df.Price[~df.Price.str.contains('/sqm')])
# Out:
# 52921

# %%
df[~df.Price.str.contains('/sqm')]
# Out:
#                                                    Title  \
# 0      Newly Built 4 Bedroom Semi Detached House With Bq
# 1          Superb 4 Bedroom Semi Detached Duplex With Bq
# 2        Furnished 2 Bedroom Terrace Duplex For Rent !!!
# 3                           2 Bedroom Apartment For Rent
# 4                      4 Bedroom Terrace Duplex For Rent
# ...                                                  ...
# 53065  A Fairly Used But Clean Mini Flat At Fola Agor...
# 53066                                          Mini Flat
# 53067                                     2 Bedroom Flat
# 53068  Alone In The Compound Newly Renovated 3bedroom...
# 53069                                 Riomself Contained
#
#                                   More Info           Price  Serviced  \
# 0                  4 BEDROOM HOUSE FOR RENT  5,000,000/year         0
# 1                  4 BEDROOM HOUSE FOR RENT  5,000,000/year         0
# ...

# %%
df = df[~df.Price.str.contains('/sqm')]

# %%
df.shape
# Out:
# (52921, 11)

# %%
df['Price'][0]
# Out:
# '5,000,000/year'

# %%
type(df['Price'][0])
# Out:
# str

# %%
df.reset_index(inplace=True)

# %%
# df.drop('index', axis=1)
df.tail()
# Out:
#        index                                              Title  \
# 52916  53065  A Fairly Used But Clean Mini Flat At Fola Agor...
# 52917  53066                                          Mini Flat
# 52918  53067                                     2 Bedroom Flat
# 52919  53068  Alone In The Compound Newly Renovated 3bedroom...
# 52920  53069                                 Riomself Contained
#
#                                   More Info    Price  Serviced  Newly Built  \
# 52916          1 BEDROOM MINI FLAT FOR RENT  500,000         0            1
# 52917          1 BEDROOM MINI FLAT FOR RENT  400,000         0            1
# 52918   2 BEDROOM FLAT / APARTMENT FOR RENT  600,000         0            0
# 52919  3 BEDROOM DETACHED BUNGALOW FOR RENT  950,000         0            0
# 52920       1 BEDROOM SELF CONTAIN FOR RENT  400,000         0            1
#
#        Furnished Bedrooms Bathrooms    Toilets  City Neighborhood
# ...

# %%
# for i in range(len(df['Price'])):
#     if df['Price'][i].endswith('/year'):
#         df['Price'][i] = int(df['Price'][i].replace('/year', '').replace(',', ''))
#     elif df['Price'][i].endswith('/month'):
#         df['Price'][i] = int(df['Price'][i ].replace('/month', '').replace(',', '')) * 12
#     elif df['Price'][i].endswith('/day'):
#         df['Price'][i] = int(df['Price'][i].replace('/day', '').replace(',', '')) * 365
#     else:
#         df['Price'][i] = int(df['Price'][i].replace(',', ''))

# %%
def format_price(x):
    if x.endswith('/year'):
        return int(x.replace('/year', '').replace(',', ''))
    elif x.endswith('/month'):
        return int(x.replace('/month', '').replace(',', '')) * 12
    else:
        return int(x.replace(',', ''))

# %%
df.Price = df.Price.apply(format_price)

# %%
df.Price.value_counts()
# Out:
# 1500000       2661
# 2500000       2479
# 3500000       2294
# 3000000       2290
# 2000000       2207
#               ...
# 39000000         1
# 144000000        1
# 8000000000       1
# 650000000        1
# 265000           1
# Name: Price, Length: 533, dtype: int64

# %%
df[df.Price == 8000000000]
# Out:
#        index           Title                            More Info       Price  \
# 20942  21015  3 Bedroom Flat  3 BEDROOM FLAT / APARTMENT FOR RENT  8000000000
#
#        Serviced  Newly Built  Furnished Bedrooms Bathrooms    Toilets   City  \
# 20942         1            0          0   3 beds   3 baths  4 Toilets  Ikoyi
#
#        Neighborhood
# 20942  Awolowo Road

# %%
df.Price.max()
# Out:
# 1700000000000

# %%
df[df.Price == df.Price.max()]
# Out:
#        index                            Title                 More Info  \
# 27367  27405  5 Bedroom Fully Detached Duplex  5 BEDROOM HOUSE FOR RENT
#
#                Price  Serviced  Newly Built  Furnished Bedrooms Bathrooms  \
# 27367  1700000000000         0            1          0   5 beds   5 baths
#
#          Toilets    City               Neighborhood
# 27367  6 Toilets  Island  Victoria Island Extension

# %%
df.shape
# Out:
# (53011, 12)

# %%
df_prc_cleaned_copy = df.copy()

# %%
df.tail()
# Out:
#        index                                              Title  \
# 53006  53065  A Fairly Used But Clean Mini Flat At Fola Agor...
# 53007  53066                                          Mini Flat
# 53008  53067                                     2 Bedroom Flat
# 53009  53068  Alone In The Compound Newly Renovated 3bedroom...
# 53010  53069                                 Riomself Contained
#
#                                   More Info   Price  Serviced  Newly Built  \
# 53006          1 BEDROOM MINI FLAT FOR RENT  500000         0            1
# 53007          1 BEDROOM MINI FLAT FOR RENT  400000         0            1
# 53008   2 BEDROOM FLAT / APARTMENT FOR RENT  600000         0            0
# 53009  3 BEDROOM DETACHED BUNGALOW FOR RENT  950000         0            0
# 53010       1 BEDROOM SELF CONTAIN FOR RENT  400000         0            1
#
#        Furnished Bedrooms Bathrooms    Toilets  City Neighborhood
# ...

# %%
type(df.Price[0])
# Out:
# int

# %%
df.dtypes
# Out:
# index            int64
# Title           object
# More Info       object
# Price           object
# Serviced         int64
# Newly Built      int64
# Furnished        int64
# Bedrooms        object
# Bathrooms       object
# Toilets         object
# City            object
# Neighborhood    object
# dtype: object

# %%
df.drop('index', axis=1, inplace=True)

# %%
df.dtypes
# Out:
# Title           object
# More Info       object
# Price           object
# Serviced         int64
# Newly Built      int64
# Furnished        int64
# Bedrooms        object
# Bathrooms       object
# Toilets         object
# City            object
# Neighborhood    object
# dtype: object

# %%
df.Price = df.Price.astype('int64')

# %%
df.dtypes
# Out:
# Title           object
# More Info       object
# Price            int64
# Serviced         int64
# Newly Built      int64
# Furnished        int64
# Bedrooms        object
# Bathrooms       object
# Toilets         object
# City            object
# Neighborhood    object
# dtype: object

# %%
df_prc_cleaned_copy['Toilets'].value_counts()
# Out:
# 4 Toilets     9919
# 0 Toilets     9411
# 3 Toilets     9287
# 1 Toilets     7263
# 5 Toilets     7238
# 2 Toilets     5429
# 6 Toilets     2265
#  Toilets      1725
# 7 Toilets      231
# 10 Toilets     138
# 8 Toilets       67
# 9 Toilets       38
# Name: Toilets, dtype: int64

# %%
df2 = df_prc_cleaned_copy.copy()

# %%
df2['Bedrooms'] = df2['Bedrooms'].str.replace('0 beds', '3')
df2['Bathrooms'] = df2['Bathrooms'].str.replace('0 baths', '3')
df2['Toilets'] = df2['Toilets'].str.replace('0 Toilets', '4')

# %%
df2.shape
# Out:
# (53011, 12)

# %%
df2['Bedrooms'].value_counts()
# Out:
# 3 beds    13755
# 1 beds    10738
# 2 beds    10196
# 4 beds     9253
# 3          4778
# 5 beds     2925
#  beds       759
# 6 beds      289
# 13          152
# 7 beds       82
# 8 beds       62
# 9 beds       22
# Name: Bedrooms, dtype: int64

# %%
df3 = df_prc_cleaned_copy.copy()

# %%
df3.head()
# Out:
#    index                                              Title  \
# 0      0  Newly Built 4 Bedroom Semi Detached House With Bq
# 1      1      Superb 4 Bedroom Semi Detached Duplex With Bq
# 2      2    Furnished 2 Bedroom Terrace Duplex For Rent !!!
# 3      3                       2 Bedroom Apartment For Rent
# 4      4                  4 Bedroom Terrace Duplex For Rent
#
#                   More Info    Price  Serviced  Newly Built  Furnished  \
# 0  4 BEDROOM HOUSE FOR RENT  5000000         0            1          0
# 1  4 BEDROOM HOUSE FOR RENT  5000000         0            1          0
# 2  2 BEDROOM HOUSE FOR RENT  3500000         1            0          0
# 3  2 BEDROOM HOUSE FOR RENT  2700000         1            1          0
# 4  4 BEDROOM HOUSE FOR RENT  4000000         1            0          0
#
#   Bedrooms Bathrooms    Toilets   City  Neighborhood
# 0   4 beds   4 baths  5 Toilets  Lekki        Agungi
# 1   4 beds   4 baths  5 Toilets  Lekki   Other Lekki
# ...

# %%
df3.drop('index', axis=1, inplace=True)
df3.head()
# Out:
#                                                Title  \
# 0  Newly Built 4 Bedroom Semi Detached House With Bq
# 1      Superb 4 Bedroom Semi Detached Duplex With Bq
# 2    Furnished 2 Bedroom Terrace Duplex For Rent !!!
# 3                       2 Bedroom Apartment For Rent
# 4                  4 Bedroom Terrace Duplex For Rent
#
#                   More Info    Price  Serviced  Newly Built  Furnished  \
# 0  4 BEDROOM HOUSE FOR RENT  5000000         0            1          0
# 1  4 BEDROOM HOUSE FOR RENT  5000000         0            1          0
# 2  2 BEDROOM HOUSE FOR RENT  3500000         1            0          0
# 3  2 BEDROOM HOUSE FOR RENT  2700000         1            1          0
# 4  4 BEDROOM HOUSE FOR RENT  4000000         1            0          0
#
#   Bedrooms Bathrooms    Toilets   City  Neighborhood
# 0   4 beds   4 baths  5 Toilets  Lekki        Agungi
# 1   4 beds   4 baths  5 Toilets  Lekki   Other Lekki
# 2   2 beds   3 baths  3 Toilets  Lekki  Osapa London
# ...

# %%
df3[['Beds', 'Rooms']] = df3.Bedrooms.str.split(" ", expand = True)

# %%
df3.head()
# Out:
#                                                Title  \
# 0  Newly Built 4 Bedroom Semi Detached House With Bq
# 1      Superb 4 Bedroom Semi Detached Duplex With Bq
# 2    Furnished 2 Bedroom Terrace Duplex For Rent !!!
# 3                       2 Bedroom Apartment For Rent
# 4                  4 Bedroom Terrace Duplex For Rent
#
#                   More Info    Price  Serviced  Newly Built  Furnished  \
# 0  4 BEDROOM HOUSE FOR RENT  5000000         0            1          0
# 1  4 BEDROOM HOUSE FOR RENT  5000000         0            1          0
# 2  2 BEDROOM HOUSE FOR RENT  3500000         1            0          0
# 3  2 BEDROOM HOUSE FOR RENT  2700000         1            1          0
# 4  4 BEDROOM HOUSE FOR RENT  4000000         1            0          0
#
#   Bedrooms Bathrooms    Toilets   City  Neighborhood Beds Rooms
# 0   4 beds   4 baths  5 Toilets  Lekki        Agungi    4  beds
# 1   4 beds   4 baths  5 Toilets  Lekki   Other Lekki    4  beds
# ...

# %%
df3.Beds.value_counts()
# Out:
# 3     13755
# 1     10738
# 2     10196
# 4      9253
# 0      4778
# 5      2925
#         759
# 6       289
# 10      152
# 7        82
# 8        62
# 9        22
# Name: Beds, dtype: int64

# %%
df3.dtypes
# Out:
# Title           object
# More Info       object
# Price           object
# Serviced         int64
# Newly Built      int64
# Furnished        int64
# Bedrooms        object
# Bathrooms       object
# Toilets         object
# City            object
# Neighborhood    object
# Beds            object
# Rooms           object
# dtype: object

# %%
df3.Beds.dtype
# Out:
# dtype('O')

# %%
df3[df3['Beds'] == ""]
# Out:
#                                                    Title  \
# 211                      A Room Selfcontain In Igbo Efon
# 217    A Spacious Room Selfcontained Apartment In A S...
# 228                                   Spacious Mini Flat
# 282                    Brand New 3 Bedroom Apartment Aus
# 395    Brand New 3 Bedroom Apartment With A Room Bq S...
# ...                                                  ...
# 52950  A Relatively New Room Self Contain At Fola Ago...
# 52967  A Relatively New Room Self Contain In A Serene...
# 52984  Very Clean Room Self Contain With Marble Tiles...
# 52990  A Newly Built Serviced Apartment To Let In A S...
# 52996  Fairly New Room Self Contain At Abule Oja, Yab...
#
#                        More Info    Price  Serviced  Newly Built  Furnished  \
# 211    FLAT / APARTMENT FOR RENT   600000         0            0          0
# 217               HOUSE FOR RENT   800000         0            0          0
# ...

# %%
def replace_with_three(x):
    if x == "":
        return "3"
    elif x == "0":
        return "3"
    else:
        return x
    
df3.Beds = df3.Beds.apply(replace_with_three)

# %%
df3.Beds.value_counts()
# Out:
# 3     19292
# 1     10738
# 2     10196
# 4      9253
# 5      2925
# 6       289
# 10      152
# 7        82
# 8        62
# 9        22
# Name: Beds, dtype: int64

# %%
len(df3.Beds)
# Out:
# 53011

# %%
df3[df3['Beds'] == ""]
# Out:
# Empty DataFrame
# Columns: [Title, More Info, Price, Serviced, Newly Built, Furnished, Bedrooms, Bathrooms, Toilets, City, Neighborhood, Beds, Rooms]
# Index: []

# %%
df3.head()
# Out:
#                                                Title  \
# 0  Newly Built 4 Bedroom Semi Detached House With Bq
# 1      Superb 4 Bedroom Semi Detached Duplex With Bq
# 2    Furnished 2 Bedroom Terrace Duplex For Rent !!!
# 3                       2 Bedroom Apartment For Rent
# 4                  4 Bedroom Terrace Duplex For Rent
#
#                   More Info    Price  Serviced  Newly Built  Furnished  \
# 0  4 BEDROOM HOUSE FOR RENT  5000000         0            1          0
# 1  4 BEDROOM HOUSE FOR RENT  5000000         0            1          0
# 2  2 BEDROOM HOUSE FOR RENT  3500000         1            0          0
# 3  2 BEDROOM HOUSE FOR RENT  2700000         1            1          0
# 4  4 BEDROOM HOUSE FOR RENT  4000000         1            0          0
#
#   Bedrooms Bathrooms    Toilets   City  Neighborhood Beds Rooms
# 0   4 beds   4 baths  5 Toilets  Lekki        Agungi    4  beds
# 1   4 beds   4 baths  5 Toilets  Lekki   Other Lekki    4  beds
# ...

# %%
df3[['Baths', 'Rooms']] = df3.Bathrooms.str.split(" ", expand = True)

# %%
df3.head()
# Out:
#                                                Title  \
# 0  Newly Built 4 Bedroom Semi Detached House With Bq
# 1      Superb 4 Bedroom Semi Detached Duplex With Bq
# 2    Furnished 2 Bedroom Terrace Duplex For Rent !!!
# 3                       2 Bedroom Apartment For Rent
# 4                  4 Bedroom Terrace Duplex For Rent
#
#                   More Info    Price  Serviced  Newly Built  Furnished  \
# 0  4 BEDROOM HOUSE FOR RENT  5000000         0            1          0
# 1  4 BEDROOM HOUSE FOR RENT  5000000         0            1          0
# 2  2 BEDROOM HOUSE FOR RENT  3500000         1            0          0
# 3  2 BEDROOM HOUSE FOR RENT  2700000         1            1          0
# 4  4 BEDROOM HOUSE FOR RENT  4000000         1            0          0
#
#   Bedrooms Bathrooms    Toilets   City  Neighborhood Beds  Rooms Baths
# 0   4 beds   4 baths  5 Toilets  Lekki        Agungi    4  baths     4
# 1   4 beds   4 baths  5 Toilets  Lekki   Other Lekki    4  baths     4
# ...

# %%
df3.Baths.value_counts()
# Out:
# 3     11444
# 1      9166
# 2      9061
# 0      9005
# 4      8532
# 5      3317
#        1628
# 6       571
# 10      119
# 7        99
# 8        46
# 9        23
# Name: Baths, dtype: int64

# %%
df3[df3['Baths'] == ""]
# Out:
#                                                    Title  \
# 202    Luxury 0ne Bedroom Share Apartment In A 4 Bedr...
# 211                      A Room Selfcontain In Igbo Efon
# 220                         2 Bedroom Apartment For Rent
# 228                                   Spacious Mini Flat
# 282                    Brand New 3 Bedroom Apartment Aus
# ...                                                  ...
# 52712  180 Square Meter Office Space For Commercial U...
# 52720               Female Bed Space Hostel @ Akoka Yaba
# 52829  Newly Built Block Of 8units Of 3bedroom Flats ...
# 52847  Newly Built Serviced & Spacious One Room Self ...
# 52984  Very Clean Room Self Contain With Marble Tiles...
#
#                                  More Info     Price  Serviced  Newly Built  \
# 202    1 BEDROOM FLAT / APARTMENT FOR RENT    900000         0            0
# 211              FLAT / APARTMENT FOR RENT    600000         0            0
# ...

# %%
df3.Baths = df3.Baths.apply(replace_with_three)

# %%
df3.Baths.value_counts()
# Out:
# 3     22077
# 1      9166
# 2      9061
# 4      8532
# 5      3317
# 6       571
# 10      119
# 7        99
# 8        46
# 9        23
# Name: Baths, dtype: int64

# %%
df3[['WC', 'Rooms']] = df3.Toilets.str.split(" ", expand = True)

# %%
df3.WC.value_counts()
# Out:
# 4     9919
# 0     9411
# 3     9287
# 1     7263
# 5     7238
# 2     5429
# 6     2265
#       1725
# 7      231
# 10     138
# 8       67
# 9       38
# Name: WC, dtype: int64

# %%
df3[df3['WC'] == ""]
# Out:
#                                                    Title  \
# 202    Luxury 0ne Bedroom Share Apartment In A 4 Bedr...
# 211                      A Room Selfcontain In Igbo Efon
# 220                         2 Bedroom Apartment For Rent
# 228                                   Spacious Mini Flat
# 282                    Brand New 3 Bedroom Apartment Aus
# ...                                                  ...
# 52599            Newly Renovated One Room Self Contained
# 52600                                     2 Bedroom Flat
# 52687                           Newly Built Self Contain
# 52829  Newly Built Block Of 8units Of 3bedroom Flats ...
# 52847  Newly Built Serviced & Spacious One Room Self ...
#
#                                     More Info     Price  Serviced  \
# 202       1 BEDROOM FLAT / APARTMENT FOR RENT    900000         0
# 211                 FLAT / APARTMENT FOR RENT    600000         0
# 220       2 BEDROOM FLAT / APARTMENT FOR RENT   2000000         0
# ...

# %%
df3.WC = df3.WC.apply(replace_with_three)

# %%
df3.WC.value_counts()
# Out:
# 3     20423
# 4      9919
# 1      7263
# 5      7238
# 2      5429
# 6      2265
# 7       231
# 10      138
# 8        67
# 9        38
# Name: WC, dtype: int64

# %%
df3.head()
# Out:
#                                                Title  \
# 0  Newly Built 4 Bedroom Semi Detached House With Bq
# 1      Superb 4 Bedroom Semi Detached Duplex With Bq
# 2    Furnished 2 Bedroom Terrace Duplex For Rent !!!
# 3                       2 Bedroom Apartment For Rent
# 4                  4 Bedroom Terrace Duplex For Rent
#
#                   More Info    Price  Serviced  Newly Built  Furnished  \
# 0  4 BEDROOM HOUSE FOR RENT  5000000         0            1          0
# 1  4 BEDROOM HOUSE FOR RENT  5000000         0            1          0
# 2  2 BEDROOM HOUSE FOR RENT  3500000         1            0          0
# 3  2 BEDROOM HOUSE FOR RENT  2700000         1            1          0
# 4  4 BEDROOM HOUSE FOR RENT  4000000         1            0          0
#
#   Bedrooms Bathrooms    Toilets   City  Neighborhood Beds    Rooms Baths WC
# 0   4 beds   4 baths  5 Toilets  Lekki        Agungi    4  Toilets     4  5
# ...

# %%
df3.Bedrooms = df3.Beds
df3.Bathrooms = df3.Baths
df3.Toilets = df3.WC

df3.drop(['Beds', 'Baths', 'WC'], axis=1, inplace=True)
df3.head()
# Out:
#                                                Title  \
# 0  Newly Built 4 Bedroom Semi Detached House With Bq
# 1      Superb 4 Bedroom Semi Detached Duplex With Bq
# 2    Furnished 2 Bedroom Terrace Duplex For Rent !!!
# 3                       2 Bedroom Apartment For Rent
# 4                  4 Bedroom Terrace Duplex For Rent
#
#                   More Info    Price  Serviced  Newly Built  Furnished  \
# 0  4 BEDROOM HOUSE FOR RENT  5000000         0            1          0
# 1  4 BEDROOM HOUSE FOR RENT  5000000         0            1          0
# 2  2 BEDROOM HOUSE FOR RENT  3500000         1            0          0
# 3  2 BEDROOM HOUSE FOR RENT  2700000         1            1          0
# 4  4 BEDROOM HOUSE FOR RENT  4000000         1            0          0
#
#   Bedrooms Bathrooms Toilets   City  Neighborhood    Rooms
# 0        4         4       5  Lekki        Agungi  Toilets
# 1        4         4       5  Lekki   Other Lekki  Toilets
# ...

# %%
df3.drop(['Rooms'], axis=1, inplace=True)

# %%
df3.head()
# Out:
#                                                Title  \
# 0  Newly Built 4 Bedroom Semi Detached House With Bq
# 1      Superb 4 Bedroom Semi Detached Duplex With Bq
# 2    Furnished 2 Bedroom Terrace Duplex For Rent !!!
# 3                       2 Bedroom Apartment For Rent
# 4                  4 Bedroom Terrace Duplex For Rent
#
#                   More Info    Price  Serviced  Newly Built  Furnished  \
# 0  4 BEDROOM HOUSE FOR RENT  5000000         0            1          0
# 1  4 BEDROOM HOUSE FOR RENT  5000000         0            1          0
# 2  2 BEDROOM HOUSE FOR RENT  3500000         1            0          0
# 3  2 BEDROOM HOUSE FOR RENT  2700000         1            1          0
# 4  4 BEDROOM HOUSE FOR RENT  4000000         1            0          0
#
#   Bedrooms Bathrooms Toilets   City  Neighborhood
# 0        4         4       5  Lekki        Agungi
# 1        4         4       5  Lekki   Other Lekki
# 2        2         3       3  Lekki  Osapa London
# ...

# %%
df3.dtypes
# Out:
# Title           object
# More Info       object
# Price           object
# Serviced         int64
# Newly Built      int64
# Furnished        int64
# Bedrooms        object
# Bathrooms       object
# Toilets         object
# City            object
# Neighborhood    object
# dtype: object

# %%
df3.Bedrooms = df3.Bedrooms.astype('int64')
df3.Bathrooms = df3.Bathrooms.astype('int64')
df3.Toilets = df3.Toilets.astype('int64')

# %%
df3.dtypes
# Out:
# Title           object
# More Info       object
# Price           object
# Serviced         int64
# Newly Built      int64
# Furnished        int64
# Bedrooms         int64
# Bathrooms        int64
# Toilets          int64
# City            object
# Neighborhood    object
# dtype: object

# %%
df3.Price = df3.Price.astype('int64')

# %%
df3.dtypes
# Out:
# Title           object
# More Info       object
# Price            int64
# Serviced         int64
# Newly Built      int64
# Furnished        int64
# Bedrooms         int64
# Bathrooms        int64
# Toilets          int64
# City            object
# Neighborhood    object
# dtype: object

# %%
df3.head()
# Out:
#                                                Title  \
# 0  Newly Built 4 Bedroom Semi Detached House With Bq
# 1      Superb 4 Bedroom Semi Detached Duplex With Bq
# 2    Furnished 2 Bedroom Terrace Duplex For Rent !!!
# 3                       2 Bedroom Apartment For Rent
# 4                  4 Bedroom Terrace Duplex For Rent
#
#                   More Info    Price  Serviced  Newly Built  Furnished  \
# 0  4 BEDROOM HOUSE FOR RENT  5000000         0            1          0
# 1  4 BEDROOM HOUSE FOR RENT  5000000         0            1          0
# 2  2 BEDROOM HOUSE FOR RENT  3500000         1            0          0
# 3  2 BEDROOM HOUSE FOR RENT  2700000         1            1          0
# 4  4 BEDROOM HOUSE FOR RENT  4000000         1            0          0
#
#    Bedrooms  Bathrooms  Toilets   City  Neighborhood
# 0         4          4        5  Lekki        Agungi
# 1         4          4        5  Lekki   Other Lekki
# 2         2          3        3  Lekki  Osapa London
# ...

# %%
df3.Bathrooms.mode()
# Out:
# 0    3
# Name: Bathrooms, dtype: int64
